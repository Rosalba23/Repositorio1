# %% [markdown]
# <a href="https://colab.research.google.com/github/Rosalba23/Repositorio1/blob/master/prueba.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("¡Hola mundo!")
# Out:
# ¡Hola mundo!

# %%
import pandas as pd
import numpy as np
import missingno as msno
# %matplotlib inline

# %%
path = '/content/enigh2018_ns_agro_csv.zip'
df = pd.read_csv(path, encoding='latin', error_bad_lines=False)
df.head()
# Out:
#     folioviv  foliohog  numren  ...  gasto_tri    ing_tri   ero_tri
# 0  100317506         1       1  ...   19565.21       0.00  19563.26
# 1  100317506         1       1  ...   95624.99   26656.63      0.00
# 2  100961704         1       1  ...   12295.08       0.00  12293.11
# 3  100961704         1       1  ...   82696.72  574025.90      0.00
# 4  101917906         1       1  ...      24.45       0.00      8.80
#
# [5 rows x 56 columns]

# %%
df.loc[30:33]
# Out:
#      folioviv  foliohog  numren  ...  gasto_tri    ing_tri  ero_tri
# 30  160006216         1       1  ...  107403.31  135301.32     0.00
# 31  160006520         1       1  ...    8804.34    9781.63     0.00
# 32  160006524         1       7  ...    2201.08       0.00  2201.08
# 33  160006524         1       7  ...    7630.43   14359.89     0.00
#
# [4 rows x 56 columns]

# %%
df.drop([0,24,51], axis=0).head()
# Out:
#     folioviv  foliohog  numren  ...  gasto_tri    ing_tri   ero_tri
# 1  100317506         1       1  ...   95624.99   26656.63      0.00
# 2  100961704         1       1  ...   12295.08       0.00  12293.11
# 3  100961704         1       1  ...   82696.72  574025.90      0.00
# 4  101917906         1       1  ...      24.45       0.00      8.80
# 5  101998619         1       1  ...     245.90       0.00    244.91
#
# [5 rows x 56 columns]

# %%
df[100:].head() #df.tail(-100) )
# Out:
#       folioviv  foliohog  numren  ...  gasto_tri   ing_tri  ero_tri
# 100  160215510         1       1  ...   14184.78  22424.67      0.0
# 101  160229801         1       3  ...    7377.04   3440.65      0.0
# 102  160229801         1       3  ...    7180.32   1788.19      0.0
# 103  160229803         1       1  ...    3590.16   6158.36      0.0
# 104  160229803         1       1  ...    8950.81  21172.13      0.0
#
# [5 rows x 56 columns]

# %%
df.apoyo.unique()
# Out:
# array([2, 1])

# %%
df.gasneg.value_counts()
# Out:
# 0         1358
# 1000       264
# 500        231
# 300        204
# 800        173
#           ...
# 91400        1
# 256000       1
# 1276         1
# 75000        1
# 1891         1
# Name: gasneg, Length: 3536, dtype: int64

# %%
df.agg(['count', 'size', 'nunique'])
# Out:
#          folioviv  foliohog  numren  ...  gasto_tri  ing_tri  ero_tri
# count       14925     14925   14925  ...      14925    14925    14925
# size        14925     14925   14925  ...      14925    14925    14925
# nunique     10159         3      11  ...       4941     4781     1763
#
# [3 rows x 56 columns]

# %%
df.groupby('apoyo').agg(['count', 'size', 'nunique']).stack()
# Out:
#                folioviv  foliohog  numren  ...  gasto_tri  ing_tri  ero_tri
# apoyo                                      ...
# 1     count        1136      1136    1136  ...       1136     1136     1136
#       size         1136      1136    1136  ...       1136     1136     1136
#       nunique      1084         2       9  ...        855      766      270
# 2     count       13789     13789   13789  ...      13789    13789    13789
#       size        13789     13789   13789  ...      13789    13789    13789
#       nunique      9642         3      11  ...       4564     4489     1623
#
# [6 rows x 55 columns]

# %%
df.tipoact.value_counts()
# Out:
# 4    7401
# 5    6958
# 6     261
# 9     247
# 7      52
# 8       6
# Name: tipoact, dtype: int64

# %%
df_sample = df.sample(frac=0.05, random_state=1)
df_sample.head()
# Out:
#          folioviv  foliohog  numren  ...  gasto_tri   ing_tri  ero_tri
# 5633   1361341224         1       1  ...      74.58    122.32      0.0
# 3836   1161699824         1       1  ...     811.47  10566.88      0.0
# 13294  3063210319         1       1  ...     190.76    296.41      0.0
# 8423   2060964308         1       1  ...      85.59    340.43      0.0
# 9218   2062504406         1       3  ...    2064.13   5561.41      0.0
#
# [5 rows x 56 columns]

# %%
df_dropped = df.dropna(subset=['prep_deriv'])
df_dropped.head()
# Out:
#     folioviv  foliohog  numren  ...  gasto_tri    ing_tri   ero_tri
# 0  100317506         1       1  ...   19565.21       0.00  19563.26
# 1  100317506         1       1  ...   95624.99   26656.63      0.00
# 2  100961704         1       1  ...   12295.08       0.00  12293.11
# 3  100961704         1       1  ...   82696.72  574025.90      0.00
# 4  101917906         1       1  ...      24.45       0.00      8.80
#
# [5 rows x 56 columns]

# %%
df_dropped.shape
# Out:
# (14925, 56)

# %%
df_copy = df.copy()
df_copy.head()
# Out:
#     folioviv  foliohog  numren  ...  gasto_tri    ing_tri   ero_tri
# 0  100317506         1       1  ...   19565.21       0.00  19563.26
# 1  100317506         1       1  ...   95624.99   26656.63      0.00
# 2  100961704         1       1  ...   12295.08       0.00  12293.11
# 3  100961704         1       1  ...   82696.72  574025.90      0.00
# 4  101917906         1       1  ...      24.45       0.00      8.80
#
# [5 rows x 56 columns]

# %%
df_copy.shape
# Out:
# (14925, 56)

# %%
df_dropped['ventas'].dtype
# Out:
# dtype('int64')

# %%
df_copy['ventas'].fillna(value=np.round(df['ventas'].mean(),decimals=0), inplace=True)

# %%
df_copy.agg(['count', 'size', 'nunique'])
# Out:
#          folioviv  foliohog  numren  ...  gasto_tri  ing_tri  ero_tri
# count       14925     14925   14925  ...      14925    14925    14925
# size        14925     14925   14925  ...      14925    14925    14925
# nunique     10159         3      11  ...       4941     4781     1763
#
# [3 rows x 56 columns]

# %%
list(df['tipoact'].unique())
# Out:
# [4, 5, 7, 6, 9, 8]

# %%
"""
4 Actividades agrícolas
5 Actividades de cría y explotación de animales
6 Actividades de recolección
7 Reforestación y tala de árboles
8 Actividades de caza y captura de animales
9 Actividades de pesca
"""
df['tipoact'].replace({4:"agrícolas", 
                       5:"animales",
                       7:"recolección", 
                       6:"tala", 
                       9:"caza", 
                       8:"pesca"}, inplace=True)

# %%
list(df['tipoact'].unique())
# Out:
# ['agrícolas', 'animales', 'recolección', 'tala', 'caza', 'pesca']

# %%
keys = list(df['tipoact'].unique())
vals = range(1,8)
act = dict(zip(keys, vals))
act
# Out:
# {'agrícolas': 1,
#  'animales': 2,
#  'caza': 5,
#  'pesca': 6,
#  'recolección': 3,
#  'tala': 4}

# %%
df_copy['tipoact_cat'] = df['tipoact'].map(act)
df_copy.head()
# Out:
#     folioviv  foliohog  numren  ...    ing_tri   ero_tri  tipoact_cat
# 0  100317506         1       1  ...       0.00  19563.26            1
# 1  100317506         1       1  ...   26656.63      0.00            2
# 2  100961704         1       1  ...       0.00  12293.11            1
# 3  100961704         1       1  ...  574025.90      0.00            2
# 4  101917906         1       1  ...       0.00      8.80            3
#
# [5 rows x 57 columns]

# %%
list(df_copy['tipoact_cat'].unique())
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
df_copy['ventas'].mean()
# Out:
# 24930.588408710217

# %%
df_copy['ventas'][df_copy['tipoact'] == 6]
# Out:
# 10       32970
# 38       25680
# 223      10750
# 243      85834
# 399       5520
#          ...
# 14373    12960
# 14379    42593
# 14451    44500
# 14486     2625
# 14492     3780
# Name: ventas, Length: 261, dtype: int64

# %%
df_copy['ventas'][df_copy['tipoact_cat'] == 6].mean()
# Out:
# 2914.6666666666665

# %%
df_copy.groupby(["tipoact_cat", "cose_cria", "prep_deriv", "otro_pago"]).count()
# Out:
#                                             folioviv  ...  ero_tri
# tipoact_cat cose_cria prep_deriv otro_pago            ...
# 1           1                    1               259  ...      259
#                                  2              7103  ...     7103
#             2         1          1                 1  ...        1
#                                  2                29  ...       29
#                       2          2                 9  ...        9
# 2           1         1          1                71  ...       71
#                                  2              4443  ...     4443
#                       2          1                86  ...       86
#                                  2              2357  ...     2357
#             2                    2                 1  ...        1
# 3           1                    1                 1  ...        1
#                                  2                50  ...       50
#             2                    2                 1  ...        1
# 4           1                    1                 1  ...        1
#                                  2               260  ...      260
# 5           1                    1                18  ...       18
#                                  2               229  ...      229
# 6           1                    2                 6  ...        6
#
# [18 rows x 53 columns]

# %%
df_copy.groupby(["tipoact_cat", "cose_cria", "prep_deriv", "otro_pago"]).count()
# Out:
#                                             folioviv  ...  ero_tri
# tipoact_cat cose_cria prep_deriv otro_pago            ...
# 1           1                    1               259  ...      259
#                                  2              7103  ...     7103
#             2         1          1                 1  ...        1
#                                  2                29  ...       29
#                       2          2                 9  ...        9
# 2           1         1          1                71  ...       71
#                                  2              4443  ...     4443
#                       2          1                86  ...       86
#                                  2              2357  ...     2357
#             2                    2                 1  ...        1
# 3           1                    1                 1  ...        1
#                                  2                50  ...       50
#             2                    2                 1  ...        1
# 4           1                    1                 1  ...        1
#                                  2               260  ...      260
# 5           1                    1                18  ...       18
#                                  2               229  ...      229
# 6           1                    2                 6  ...        6
#
# [18 rows x 53 columns]

# %%
df_copy.groupby(["tipoact", "cose_cria"])[["prep_deriv", "otro_pago"]].count()
# Out:
#                    prep_deriv  otro_pago
# tipoact cose_cria
# 4       1                7362       7362
#         2                  39         39
# 5       1                6957       6957
#         2                   1          1
# 6       1                 261        261
# 7       1                  51         51
#         2                   1          1
# 8       1                   6          6
# 9       1                 247        247

# %%
df_copy.tipoact
# Out:
# 0        4
# 1        5
# 2        4
# 3        5
# 4        7
#         ..
# 14920    5
# 14921    4
# 14922    5
# 14923    4
# 14924    5
# Name: tipoact, Length: 14925, dtype: int64

# %%
df_sample = df.sample(frac=0.05, random_state=1)
df_sample.head()
# Out:
#          folioviv  foliohog  numren  ...  gasto_tri   ing_tri  ero_tri
# 5633   1361341224         1       1  ...      74.58    122.32      0.0
# 3836   1161699824         1       1  ...     811.47  10566.88      0.0
# 13294  3063210319         1       1  ...     190.76    296.41      0.0
# 8423   2060964308         1       1  ...      85.59    340.43      0.0
# 9218   2062504406         1       3  ...    2064.13   5561.41      0.0
#
# [5 rows x 56 columns]

# %%
df_sample.groupby(["tipoact", "cose_cria"])[["prep_deriv", "otro_pago"]].agg([np.sum, np.mean,
                                                              np.count_nonzero])
# Out:
#                       otro_pago
#                             sum      mean count_nonzero
# tipoact     cose_cria
# agrícolas   1               729  1.970270           370
#             2                 4  2.000000             2
# animales    1               686  1.971264           348
#             2                 2  2.000000             1
# caza        1                18  1.800000            10
# recolección 1                 2  2.000000             1
# tala        1                28  2.000000            14

# %%
df_sample.groupby(["tipoact", "cose_cria"]).agg({'ventas':np.mean,'otro_pago':np.max})
# Out:
#                               ventas  otro_pago
# tipoact     cose_cria
# agrícolas   1           23868.200000          2
#             2               0.000000          2
# animales    1           17341.959770          2
#             2               0.000000          2
# caza        1          108393.700000          2
# recolección 1            9000.000000          2
# tala        1           22991.285714          2

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

ax1 = plt.axes()  # standard axes
ax2 = plt.axes([0.65, 0.65, 0.2, 0.2])

# %%
fig = plt.figure()
ax1 = fig.add_axes([0.1, 0.5, 0.8, 0.4],
                   xticklabels=[], ylim=(-1.2, 1.2))
ax2 = fig.add_axes([0.1, 0.1, 0.8, 0.4],
                   ylim=(-1.2, 1.2))

x = np.linspace(0, 10)
ax1.plot(np.sin(x))
ax2.plot(np.cos(x))

# %%
for i in range(1, 7):
    plt.subplot(2, 3, i)
    plt.text(0.5, 0.5, str((2, 3, i)),
             fontsize=18, ha='center')

# %%
fig = plt.figure()
fig.subplots_adjust(hspace=0.4, wspace=0.4)
for i in range(1, 7):
    ax = fig.add_subplot(2, 3, i)
    ax.text(0.5, 0.5, str((2, 3, i)),
           fontsize=18, ha='center')

# %%
fig, ax = plt.subplots(2, 3, sharex='col', sharey='row')

# %%
for i in range(2):
    for j in range(3):
        ax[i, j].text(0.5, 0.5, str((i, j)),
                      fontsize=18, ha='center')
fig

# %%
mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(mean, cov, 3000).T

# Set up the axes with gridspec
fig = plt.figure(figsize=(6, 6))
grid = plt.GridSpec(4, 4, hspace=0.2, wspace=0.2)
main_ax = fig.add_subplot(grid[:-1, 1:])
y_hist = fig.add_subplot(grid[:-1, 0], xticklabels=[], sharey=main_ax)
x_hist = fig.add_subplot(grid[-1, 1:], yticklabels=[], sharex=main_ax)

# scatter points on the main axes
main_ax.plot(x, y, 'ok', markersize=3, alpha=0.2)

# histogram on the attached axes
x_hist.hist(x, 40, histtype='stepfilled',
            orientation='vertical', color='gray')
x_hist.invert_yaxis()

y_hist.hist(y, 40, histtype='stepfilled',
            orientation='horizontal', color='gray')
y_hist.invert_xaxis()

# %%
df_sample['ventas'] = df_sample['ventas'].astype('int64')

df_sample.plot(kind='scatter',x='ventas',y='tipoact')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-ba76a60d84a4> in <module>()
#       1 df_sample['ventas'] = df_sample['ventas'].astype('int64')
#       2
# ----> 3 df_sample.plot(kind='scatter',x='ventas',y='tipoact')
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     736         if kind in self._dataframe_kinds:
#     737             if isinstance(data, ABCDataFrame):
# --> 738                 return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     739             else:
#     740                 raise ValueError(
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59                 ax = plt.gca()
#      60             kwargs["ax"] = getattr(ax, "left_ax", ax)
# ---> 61     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
#      62     plot_obj.generate()
#      63     plot_obj.draw()
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/core.py in __init__(self, data, x, y, s, c, **kwargs)
#     928             # the handling of this argument later
#     929             s = 20
# --> 930         super().__init__(data, x, y, s=s, **kwargs)
#     931         if is_integer(c) and not self.data.columns.holds_integer():
#     932             c = self.data.columns[c]
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/core.py in __init__(self, data, x, y, **kwargs)
#     870             raise ValueError(self._kind + " requires x column to be numeric")
#     871         if len(self.data[y]._get_numeric_data()) == 0:
# --> 872             raise ValueError(self._kind + " requires y column to be numeric")
#     873
#     874         self.x = x
#
# ValueError: scatter requires y column to be numeric

# %%
df_sample['ventas'] = df_sample['ventas'].astype('int64')

# %%
df_sample.plot(kind='scatter',x='ventas',y='tipoact')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-1c439e7031c7> in <module>()
# ----> 1 df_sample.plot(kind='scatter',x='ventas',y='tipoact')
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     736         if kind in self._dataframe_kinds:
#     737             if isinstance(data, ABCDataFrame):
# --> 738                 return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     739             else:
#     740                 raise ValueError(
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59                 ax = plt.gca()
#      60             kwargs["ax"] = getattr(ax, "left_ax", ax)
# ---> 61     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
#      62     plot_obj.generate()
#      63     plot_obj.draw()
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/core.py in __init__(self, data, x, y, s, c, **kwargs)
#     928             # the handling of this argument later
#     929             s = 20
# --> 930         super().__init__(data, x, y, s=s, **kwargs)
#     931         if is_integer(c) and not self.data.columns.holds_integer():
#     932             c = self.data.columns[c]
#
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/core.py in __init__(self, data, x, y, **kwargs)
#     870             raise ValueError(self._kind + " requires x column to be numeric")
#     871         if len(self.data[y]._get_numeric_data()) == 0:
# --> 872             raise ValueError(self._kind + " requires y column to be numeric")
#     873
#     874         self.x = x
#
# ValueError: scatter requires y column to be numeric

# %%
plt.hist(df_sample['tipoact'])
plt.xlabel('tipoact')
plt.ylabel('Frequency')
plt.title('Frequency of tipoact')
# Out:
# Text(0.5, 1.0, 'Frequency of tipoact')

# %%
plt.hist(df_sample['ventas'])
plt.xlabel('ventas')
plt.ylabel('Frequency')
plt.title('Frequency of ventas')
# Out:
# Text(0.5, 1.0, 'Frequency of ventas')

# %%
plt.boxplot(df_sample['ventas'], showmeans=True, meanline=True)
plt.ylabel('ventas count')
plt.title('Box Plot of ventas count')
# Out:
# Text(0.5, 1.0, 'Box Plot of ventas count')
