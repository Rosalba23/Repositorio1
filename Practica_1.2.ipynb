# %% [markdown]
# <a href="https://colab.research.google.com/github/Rosalba23/Repositorio1/blob/master/Practica_1.2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import missingno as msno
# %matplotlib inline

# %%
path = '/content/hotel_bookings.csv.zip'
df = pd.read_csv(path, encoding='latin', error_bad_lines=False)
df.head()
# Out:
#           hotel  is_canceled  ...  reservation_status  reservation_status_date
# 0  Resort Hotel            0  ...           Check-Out               2015-07-01
# 1  Resort Hotel            0  ...           Check-Out               2015-07-01
# 2  Resort Hotel            0  ...           Check-Out               2015-07-02
# 3  Resort Hotel            0  ...           Check-Out               2015-07-02
# 4  Resort Hotel            0  ...           Check-Out               2015-07-03
#
# [5 rows x 32 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
# hotel                             119390 non-null object
# is_canceled                       119390 non-null int64
# lead_time                         119390 non-null int64
# arrival_date_year                 119390 non-null int64
# arrival_date_month                119390 non-null object
# arrival_date_week_number          119390 non-null int64
# arrival_date_day_of_month         119390 non-null int64
# stays_in_weekend_nights           119390 non-null int64
# stays_in_week_nights              119390 non-null int64
# adults                            119390 non-null int64
# children                          119386 non-null float64
# babies                            119390 non-null int64
# meal                              119390 non-null object
# country                           118902 non-null object
# market_segment                    119390 non-null object
# ...

# %%
df.shape
# Out:
# (119390, 32)

# %%
df.shape[0]
# Out:
# 119390

# %%
df.shape[1]
# Out:
# 32

# %%
df.columns.values.tolist()
# Out:
# ['hotel',
#  'is_canceled',
#  'lead_time',
#  'arrival_date_year',
#  'arrival_date_month',
#  'arrival_date_week_number',
#  'arrival_date_day_of_month',
#  'stays_in_weekend_nights',
#  'stays_in_week_nights',
#  'adults',
#  'children',
#  'babies',
#  'meal',
#  'country',
#  'market_segment',
#  'distribution_channel',
#  'is_repeated_guest',
#  'previous_cancellations',
#  'previous_bookings_not_canceled',
#  'reserved_room_type',
#  'assigned_room_type',
#  'booking_changes',
#  'deposit_type',
#  'agent',
#  'company',
#  'days_in_waiting_list',
#  'customer_type',
#  'adr',
#  'required_car_parking_spaces',
#  'total_of_special_requests',
#  'reservation_status',
#  'reservation_status_date']

# %%
df.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
df.isnull().any().any()
# Out:
# True

# %%
msno.matrix(df)

# %%
msno.matrix(df)

# %%
msno.bar(df)

# %%
df.columns[df.isnull().any()].tolist()
# Out:
# ['children', 'country', 'agent', 'company']

# %%
df.describe()
# Out:
#          is_canceled  ...  total_of_special_requests
# count  119390.000000  ...              119390.000000
# mean        0.370416  ...                   0.571363
# std         0.482918  ...                   0.792798
# min         0.000000  ...                   0.000000
# 25%         0.000000  ...                   0.000000
# 50%         0.000000  ...                   0.000000
# 75%         1.000000  ...                   1.000000
# max         1.000000  ...                   5.000000
#
# [8 rows x 20 columns]

# %%
df.loc[[0]]
# Out:
#           hotel  is_canceled  ...  reservation_status  reservation_status_date
# 0  Resort Hotel            0  ...           Check-Out               2015-07-01
#
# [1 rows x 32 columns]

# %%
df.loc[30:33]
# Out:
#            hotel  is_canceled  ...  reservation_status  reservation_status_date
# 30  Resort Hotel            0  ...           Check-Out               2015-07-15
# 31  Resort Hotel            0  ...           Check-Out               2015-07-16
# 32  Resort Hotel            1  ...            Canceled               2015-05-29
# 33  Resort Hotel            0  ...           Check-Out               2015-07-08
#
# [4 rows x 32 columns]

# %%
df.drop([0,24,51], axis=0).head()
# Out:
#           hotel  is_canceled  ...  reservation_status  reservation_status_date
# 1  Resort Hotel            0  ...           Check-Out               2015-07-01
# 2  Resort Hotel            0  ...           Check-Out               2015-07-02
# 3  Resort Hotel            0  ...           Check-Out               2015-07-02
# 4  Resort Hotel            0  ...           Check-Out               2015-07-03
# 5  Resort Hotel            0  ...           Check-Out               2015-07-03
#
# [5 rows x 32 columns]

# %%
df.drop(df.index[1:5], axis=0).head(10)
# Out:
#            hotel  is_canceled  ...  reservation_status  reservation_status_date
# 0   Resort Hotel            0  ...           Check-Out               2015-07-01
# 5   Resort Hotel            0  ...           Check-Out               2015-07-03
# 6   Resort Hotel            0  ...           Check-Out               2015-07-03
# 7   Resort Hotel            0  ...           Check-Out               2015-07-03
# 8   Resort Hotel            1  ...            Canceled               2015-05-06
# 9   Resort Hotel            1  ...            Canceled               2015-04-22
# 10  Resort Hotel            1  ...            Canceled               2015-06-23
# 11  Resort Hotel            0  ...           Check-Out               2015-07-05
# 12  Resort Hotel            0  ...           Check-Out               2015-07-05
# 13  Resort Hotel            0  ...           Check-Out               2015-07-05
#
# [10 rows x 32 columns]

# %%
df[100:].head() #df.tail(-100) )
# Out:
#             hotel  is_canceled  ...  reservation_status  reservation_status_date
# 100  Resort Hotel            0  ...           Check-Out               2015-07-07
# 101  Resort Hotel            0  ...           Check-Out               2015-07-07
# 102  Resort Hotel            0  ...           Check-Out               2015-07-10
# 103  Resort Hotel            0  ...           Check-Out               2015-07-10
# 104  Resort Hotel            0  ...           Check-Out               2015-07-11
#
# [5 rows x 32 columns]

# %%
df.adults.values
# Out:
# array([2, 2, 1, ..., 2, 2, 2])

# %%
df['adults'].values
# Out:
# array([2, 2, 1, ..., 2, 2, 2])

# %%
df.adults.unique()
# Out:
# array([ 2,  1,  3,  4, 40, 26, 50, 27, 55,  0, 20,  6,  5, 10])

# %%
df.adults.value_counts()
# Out:
# 2     89680
# 1     23027
# 3      6202
# 0       403
# 4        62
# 26        5
# 27        2
# 20        2
# 5         2
# 55        1
# 50        1
# 40        1
# 10        1
# 6         1
# Name: adults, dtype: int64

# %%
df.agg(['count', 'size', 'nunique'])
# Out:
#           hotel  is_canceled  ...  reservation_status  reservation_status_date
# count    119390       119390  ...              119390                   119390
# size     119390       119390  ...              119390                   119390
# nunique       2            2  ...                   3                      926
#
# [3 rows x 32 columns]

# %%
df.groupby('adults').agg(['count', 'size', 'nunique']).stack()
# Out:
#                 hotel  is_canceled  ...  reservation_status  reservation_status_date
# adults                              ...
# 0      count      403          403  ...                 403                      403
#        size       403          403  ...                 403                      403
#        nunique      2            2  ...                   3                      274
# 1      count    23027        23027  ...               23027                    23027
#        size     23027        23027  ...               23027                    23027
#        nunique      2            2  ...                   3                      839
# 2      count    89680        89680  ...               89680                    89680
#        size     89680        89680  ...               89680                    89680
#        nunique      2            2  ...                   3                      919
# 3      count     6202         6202  ...                6202                     6202
# ...

# %%
df.groupby('adults').agg(['count', 'size', 'nunique'])
# Out:
#         hotel                 ... reservation_status_date
#         count   size nunique  ...                   count   size nunique
# adults                        ...
# 0         403    403       2  ...                     403    403     274
# 1       23027  23027       2  ...                   23027  23027     839
# 2       89680  89680       2  ...                   89680  89680     919
# 3        6202   6202       2  ...                    6202   6202     792
# 4          62     62       2  ...                      62     62      55
# 5           2      2       1  ...                       2      2       1
# 6           1      1       1  ...                       1      1       1
# 10          1      1       1  ...                       1      1       1
# 20          2      2       1  ...                       2      2       2
# 26          5      5       1  ...                       5      5       1
# 27          2      2       1  ...                       2      2       1
# ...

# %%
df_sample = df.sample(frac=0.05, random_state=1)
df_sample.head()
# Out:
#               hotel  is_canceled  ...  reservation_status  reservation_status_date
# 8030   Resort Hotel            1  ...            Canceled               2016-02-09
# 37532  Resort Hotel            0  ...           Check-Out               2017-06-21
# 76865    City Hotel            1  ...            Canceled               2015-08-17
# 1960   Resort Hotel            0  ...           Check-Out               2015-09-27
# 98971    City Hotel            0  ...           Check-Out               2016-10-07
#
# [5 rows x 32 columns]

# %%
df.shape
# Out:
# (119390, 32)

# %%
df_sample.shape
# Out:
# (5970, 32)

# %%
df_dropped = df.dropna(subset=['is_canceled'])
df_dropped.head()
# Out:
#           hotel  is_canceled  ...  reservation_status  reservation_status_date
# 0  Resort Hotel            0  ...           Check-Out               2015-07-01
# 1  Resort Hotel            0  ...           Check-Out               2015-07-01
# 2  Resort Hotel            0  ...           Check-Out               2015-07-02
# 3  Resort Hotel            0  ...           Check-Out               2015-07-02
# 4  Resort Hotel            0  ...           Check-Out               2015-07-03
#
# [5 rows x 32 columns]

# %%
df_dropped.shape
# Out:
# (119390, 32)

# %%
df_copy = df.copy()
df_copy.head()
# Out:
#           hotel  is_canceled  ...  reservation_status  reservation_status_date
# 0  Resort Hotel            0  ...           Check-Out               2015-07-01
# 1  Resort Hotel            0  ...           Check-Out               2015-07-01
# 2  Resort Hotel            0  ...           Check-Out               2015-07-02
# 3  Resort Hotel            0  ...           Check-Out               2015-07-02
# 4  Resort Hotel            0  ...           Check-Out               2015-07-03
#
# [5 rows x 32 columns]

# %%
df_copy.shape
# Out:
# (119390, 32)

# %%
df_dropped['adr'].dtype
# Out:
# dtype('float64')

# %%
df_dropped['adr'].mean()
# Out:
# 101.83112153446453

# %%
df_copy['adr'].fillna(value=np.round(df['adr'].mean(),decimals=0), inplace=True)

# %%
df_copy.agg(['count', 'size', 'nunique'])
# Out:
#           hotel  is_canceled  ...  reservation_status  reservation_status_date
# count    119390       119390  ...              119390                   119390
# size     119390       119390  ...              119390                   119390
# nunique       2            2  ...                   3                      926
#
# [3 rows x 32 columns]

# %%
list(df['arrival_date_month'].unique())
# Out:
# ['July',
#  'August',
#  'September',
#  'October',
#  'November',
#  'December',
#  'January',
#  'February',
#  'March',
#  'April',
#  'May',
#  'June']

# %%
df['arrival_date_month'].replace({January:"1",
                       February:"2",
                       March:"3",
                       April:"4",
                       May:"5", 
                       June:"6", 
                       July:"7", 
                       August:"8",
                       September:"9", 
                       October:"10", 
                       November:"11", 
                       December:"12"}, 
                       inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-4adc09a8246c> in <module>()
#       1
#       2 df['arrival_date_month'].replace({"January":"1",
# ----> 3                        February:"2",
#       4                        March:"3",
#       5                        April:"4",
#
# NameError: name 'February' is not defined

# %%
list(df['arrival_date_month'].unique())
# Out:
# ['July',
#  'August',
#  'September',
#  'October',
#  'November',
#  'December',
#  'January',
#  'February',
#  'March',
#  'April',
#  'May',
#  'June']
